# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15,10))

# %%
datos = pd.read_csv('alquiler_residencial_sin_outliers.csv', sep=';')
datos.head(10)
# Out:
#       Tipo           Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0  Almacén  Villa El Salvador        0         6       0  2236  40000.0
# 1  Almacén         San Miguel        0         3       0  1000   9800.0
# 2  Almacén              Comas        0         0       0   550   4300.0
# 3  Almacén      Puente Piedra        0         0       0  1096  12000.0
# 4  Almacén         Chaclacayo        0         3       0   404  15000.0
# 5  Almacén              Lince        0         3       0   300   6000.0
# 6  Almacén              Lince        0         0       0  1000   8000.0
# 7  Almacén        Punta Negra        0        20       0  1100  16000.0
# 8  Almacén         San Isidro        0         0       0   850   8500.0
# 9  Almacén           La Punta        0         0       0  2000  30000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0            0.0       0.0     17.89  Departamento
# 1            0.0     820.0      9.80  Departamento
# 2            0.0       0.0      7.82  Departamento
# 3            0.0    1771.0     10.95  Departamento
# 4            0.0     370.0     37.13  Departamento
# 5            0.0       0.0     20.00  Departamento
# 6            0.0       0.0      8.00  Departamento
# 7            0.0    2435.0     14.55  Departamento
# 8            0.0       0.0     10.00  Departamento
# 9            0.0       0.0     15.00  Departamento

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2,2,1)
g2 = area.add_subplot(2,2,2)
g3 = area.add_subplot(2,2,3)
g4 = area.add_subplot(2,2,4)

# %%
# creating plots
g1.scatter(datos.Valor, datos.Area)
g1.set_title('Valor x Area')

g2.hist(datos.Valor)
g2.set_title('Histograma de Valor')

datos_g3 = datos.Valor.sample(100)
datos_g3.index = range(datos_g3.shape[0])
g3.plot(datos_g3)
g3.set_title('Muestra Valor')

grupo = datos.groupby('Tipo')['Valor']
label = grupo.mean().index
valores = grupo.mean().values
g4.bar(label, valores)
g4.set_title('Valor medio por Tipo')
# Out:
# Text(0.5, 1.0, 'Valor medio por Tipo')

# %%
area

# %%
area.savefig('grafico.png', dpi = 300, bbox_inches= 'tight')
